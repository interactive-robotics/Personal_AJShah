# %% [markdown]
# # Data analysis for Simulated Runs

# %%
from Auto_Eval_Active import *
import auto_eval_params as params
from AutoEvalAnalysis import *
import dill
import os

data = {}
data[5] = {}
data[6] = {}

# %% [markdown]
# **Import the data for the run with 2 demos and 3 queries**

# %%
params.results_path = '/home/ajshah/Results/Results_5'
data[5]['Entropy'] = report_entropies()
data[5]['Similarity'] = report_similarities()

params.results_path = '/home/ajshah/Results/Results_6'
data[6]['Entropy'] = report_entropies()
data[6]['Similarity'] = report_similarities()

# %%
np.mean(data[5]['Entropy'])
# Out:
# Active    1.756648
# Batch     1.513680
# Random    2.584167
# dtype: float64

# %%
np.mean(data[5]['Similarity'])
# Out:
# Active    0.773822
# Batch     0.647392
# Random    0.691122
# dtype: float64

# %%
plot_entropy(data[5]['Entropy'])

# %%
plot_similarity(data[5]['Similarity'])
# Out:
# No handles with labels found to put in legend.

# %%
np.mean(data[6]['Entropy'])
# Out:
# Active    1.272410
# Batch     1.281970
# Random    2.458167
# dtype: float64

# %%
np.mean(data[6]['Similarity'])
# Out:
# Active    0.843884
# Batch     0.654849
# Random    0.697468
# dtype: float64

# %%
plot_entropy(data[6]['Entropy'])

# %%
plot_similarity(data[6]['Similarity'])
# Out:
# No handles with labels found to put in legend.
